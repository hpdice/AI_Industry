# %% [markdown]
# # py 는 데이터 드리블이 어려웠음
#
# ## ipynb  = i python notebook file
#     : 편리한 마크다운 기능 md
#
# ### ipynb 작업 정리
#
# 셀 클릭 하고
#
# 1) m : 마크다운으로 변환
# 2) y : 코드로 변환
# 3) a : 위에 코드 셀 추가 above
# 4) b : 아래에 코드 셀 추가 below
# 5) d + d : 셀 삭제 ( shift 다중 선택 )
#
# 6) ctrl + enter : 현재 셀에서 작업
# 7) shift + enter : 현재 셀에서 작업 이후 다음 셀로 이동

# %%
a = 5 
a
# Out:
# 5

# %%
c = "최영준"
c
# Out:
# '최영준'

# %%
a = 35
b = 67 

a * b
# Out:
# 2345

# %% [markdown]
# ## 2. 변수 규칙

# %% [markdown]
# 주석은 문자에 필요한 항목만 작성

# %%
# 변수 이름은 숫자로 시작할 수 없음 = 오류 
2var = "행복"
# Out:
#   Cell In[6], line 2
#     2var = "행복"
#     ^
# SyntaxError: invalid decimal literal

# %%
# 변수 이름에 공백이 들어가는 변수 - 오류 
happy var = "행복"
# Out:
#   Cell In[7], line 2
#     happy var = "행복"
#           ^
# SyntaxError: invalid syntax

# %%
# _ 을 사용하여 변수 작성 
happy_var = "행복"

# %%
# 특수기호를 변수에 포함시키면 오류 
happy_var! = "행복"
# Out:
#   Cell In[9], line 2
#     happy_var! = "행복"
#              ^
# SyntaxError: invalid syntax

# %%
abc = 5
abc
# Out:
# 5

# %%
ABC = "Apple"
ABC
# Out:
# 'Apple'

# %% [markdown]
# 변수는 대소문자를 구분한다

# %%
x , y, z = 1,2,3

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 3
