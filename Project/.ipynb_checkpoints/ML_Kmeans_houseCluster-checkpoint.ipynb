# %% [markdown]
# # 주택군집
#
# ## K-Means
#      - Target : 주택 판매 가격
#      - EDA
#      - StandardScaler 표준화
#      - LostArea , GrLivArea , SalePrice만 선택
#      - 산점도에 군집 색상 표시
#      - Groupby 군집별 평균 - 소/중/대 그룹 해석
