# %% [markdown]
# # 시작하는 글
#
# 왜 Python이 AI 패러다임 언어로 쓰이는가 - 생성형 AI
# Python + Physical AI , Python이 C 와 C++ 를 이용하게 하는 매개체
# Open 개방형 언어 , 여러 라이브러리를 사용 가능

# %% [markdown]
# 자료구조는 Cart , Container로 생각 , 자료를 잘 담는게 중요하다.
# python은 자료구조가 필요없음
#
# # List는 AI 패러다임에서 가장 중요한 구조이다 !!!

# %%
score_1 = 80
score_2 = 90
scroe_3 = 100
score_4 = 70
score_5 = 60
score_6 = 50
score_7 = 80
score_8 = 90
score_9 = 100
score_10 = 70

# %%
score = [80,90,100,70,60,50,80,90,100,70]
score
# Out:
# [80, 90, 100, 70, 60, 50, 80, 90, 100, 70]

# %% [markdown]
# 1.리스트(List) : []

# %%
fruit_list = ['apple','banana','orange']
fruit_list
# Out:
# ['apple', 'banana', 'orange']

# %%
# List 자료형은 원소(item) 중복이 허용된다.
fruit_list = ['apple','banana','orange','apple','banana']
fruit_list
# Out:
# ['apple', 'banana', 'orange', 'apple', 'banana']

# %% [markdown]
# 원소 순서
#
# [0][1][2]....[-3][-2][-1]

# %% [markdown]
# item selection

# %%
fruit_list[0]
# Out:
# 'apple'

# %%
fruit_list[-1]
# Out:
# 'banana'

# %%
len(fruit_list)
# Out:
# 5

# %%
# Start:End --> End is not included 
fruit_list[2:4]
# Out:
# ['orange', 'apple']

# %%
fruit_list[:3]
# Out:
# ['apple', 'banana', 'orange']

# %%
fruit_list[-3:5]
# Out:
# ['orange', 'apple', 'banana']

# %%
fruit_list[1] = 'kiwi'
fruit_list
# Out:
# ['apple', 'kiwi', 'orange', 'apple', 'banana']

# %%
fruit_list[1:2] = ['strawberry','blueberry']
fruit_list
# Out:
# ['apple', 'strawberry', 'blueberry', 'blueberry', 'apple', 'banana']

# %%
fruit_list[3] = "orange"
fruit_list[4] = 'apple'

# %%
fruit_list
# Out:
# ['apple', 'strawberry', 'blueberry', 'orange', 'apple', 'banana']

# %%
fruit_list.insert(2,'mango')
fruit_list
# Out:
# ['apple', 'strawberry', 'mango', 'blueberry', 'orange', 'apple', 'banana']

# %%
# n) appendix - 부록 , 붙이기 (추가)  
# v) append 
fruit_list.append('watermelon')
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon']

# %%
fruit_list.append('melon')
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon']

# %%
vegetable_list = ['carrot','onion','tomato']
vegetable_list
# Out:
# ['carrot', 'onion', 'tomato']

# %%
fruit_list.extend(vegetable_list)
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon',
#  'carrot',
#  'onion',
#  'tomato']

# %%
fruit_list.remove('carrot')
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon',
#  'onion',
#  'tomato']

# %%
# del 예약어 - undo 가 안됌.
del fruit_list[-1]

# %%
fruit_list
# Out:
# ['apple',
#  'strawberry',
#  'mango',
#  'blueberry',
#  'orange',
#  'apple',
#  'banana',
#  'watermelon',
#  'melon',
#  'onion']

# %%
fruit_list.clear()

# %%
fruit_list
# Out:
# []

# %%
fruit_list = ['apple',
 'strawberry',
 'mango',
 'blueberry',
 'orange',
 'apple',
 'banana',
 'watermelon',
 'melon',
 'onion',
 'tomato']

# %%
fruit_list.sort()
fruit_list
# Out:
# ['apple',
#  'apple',
#  'banana',
#  'blueberry',
#  'mango',
#  'melon',
#  'onion',
#  'orange',
#  'strawberry',
#  'tomato',
#  'watermelon']

# %%
fruit_list.sort(reverse=True)
fruit_list
# Out:
# ['watermelon',
#  'tomato',
#  'strawberry',
#  'orange',
#  'onion',
#  'melon',
#  'mango',
#  'blueberry',
#  'banana',
#  'apple',
#  'apple']

# %% [markdown]
# # 2 . 튜플 (tuple) : ( )

# %%
fruit_list = ('apple','banana','orange')
fruit_list
# Out:
# ('apple', 'banana', 'orange')

# %%
# Tuple은 아이템 변경이 불가능 , 변수값 선언 방식 허용 X
# but List는 아이템 변경이 가능 

fruit_list[1] = 'kiwi'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 4
#       1 # Tuple은 아이템 변경이 불가능 , 변수값 선언 방식 허용 X
#       2 # but List는 아이템 변경이 가능
#       3
# ----> 4 fruit_list[1] = 'kiwi'
#
# TypeError: 'tuple' object does not support item assignment
