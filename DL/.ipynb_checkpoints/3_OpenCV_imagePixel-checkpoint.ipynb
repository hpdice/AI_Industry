# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("./data/rear_garden.PNG")

# %%
# 이미지 출력
print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
# Out:
# width: 819 pixels
# height: 496 pixels
# channels: 3

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# 이미지의 특정 위치 = Pixel (BGR) 

(b,g,r) = img[0,0]
print("Pixel at (0,0) - Red : {} , Green : {} , Blue : {}".format(r,g,b))
# Out:
# Pixel at (0,0) - Red : 8 , Green : 20 , Blue : 18

# %%
# 이미지에서 특정한 범위만 지정하여 cut
ROI = img[50:100 , 50:100]

plt.imshow(cv2.cvtColor(ROI,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# 이미지에서 특정한 범위만 지정하여 cut
ROI = img[50:100 , 50:100] = (0,0,255) # 빨간색(BGR)

plt.imshow(cv2.cvtColor(ROI,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[27], line 4
#       1 # 이미지에서 특정한 범위만 지정하여 cut
#       2 ROI = img[50:100 , 50:100] = (0,0,255) # 빨간색(BGR)
# ----> 4 plt.imshow(cv2.cvtColor(ROI,cv2.COLOR_BGR2RGB))
#       5 plt.axis('off')
#       6 plt.show()
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:94: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0xa0d16e95::Set<3,4,-1>,struct cv::impl::A0xa0d16e95::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Unsupported depth of input image:
# >     'VDepth::contains(depth)'
# > where
# >     'depth' is 6 (CV_64F)

# %%
# 이미지에서 특정한 범위만 지정하여 cut
ROI = img[50:100 , 50:100] = (0,0,255) # 빨간색(BGR)

plt.imshow(cv2.cvtColor(ROI,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 4
#       1 # 이미지에서 특정한 범위만 지정하여 cut
#       2 ROI = img[50:100 , 50:100] = (0,0,255) # 빨간색(BGR)
# ----> 4 plt.imshow(cv2.cvtColor(ROI,cv2.COLOR_BGR2RGB))
#       5 plt.axis('off')
#       6 plt.show()
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:94: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0xa0d16e95::Set<3,4,-1>,struct cv::impl::A0xa0d16e95::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Unsupported depth of input image:
# >     'VDepth::contains(depth)'
# > where
# >     'depth' is 6 (CV_64F)
