# %% [markdown]
# ### CIFAR-10 이미지 분류

# %% [markdown]
# - ML : sklearn
# - DL
#     - tensorflow v2
#         - keras :
#         - tensorflow와 keras 가 충돌하는 경우가 생김
#     - pytorch

# %%
# import sys

# !{sys.executable} -m pip list --outdated

# 가장 최신버전으로 업데이트

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# cifar10
import keras
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import cifar10

from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix , classification_report

# 한글 패치 표준

plt.rcParams['font.family'] = 'Malgun Gothic' # apple : 'AppleGothic'

# 마이너스 부호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False
# Out:
# C:\Users\cyj\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
print(tf.__version__)
# Out:
# 2.21.0

# %%
print(keras.__version__)
# Out:
# 3.15.0

# %%
# CIFAR - 10 데이터셋 로드
(X_train,y_train),(X_test,y_test) = cifar10.load_data()

# 데이터 형태 확인
print(f"학습 데이터 형태(X_train) : {X_train.shape}")
print(f"학습 레이블 형태(y_train) : {y_train.shape}")
print(f"테스트 데이터 형태(X_test) : {X_test.shape}")
print(f"테스트 데이터 형태(y_test) : {X_test.shape}")
# Out:
# ...
#  11935744/170498071 ━━━━━━━━━━━━━━━━━━━━ 4:31:26 103us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # CIFAR - 10 데이터셋 로드
# ----> 2 (X_train,y_train),(X_test,y_test) = cifar10.load_data()
#       4 # 데이터 형태 확인
#       5 print(f"학습 데이터 형태(X_train) : {X_train.shape}")
#
# File C:\Users\cyj\Lib\site-packages\keras\src\datasets\cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
# ...
